# %%
# %load_ext bigdata
# %pig_start
# %timeout 300
# !hadoop fs -rm data.tsv
# !hadoop fs -put data.tsv
# !hadoop fs -ls
# Out:
# The bigdata extension is already loaded. To reload it, use:
#   %reload_ext bigdata
# Deleted data.tsv
# Found 1 items
# -rw-r--r--   1 root supergroup       1780 2020-03-06 14:05 data.tsv

# %%
# !hadoop fs -cat data.tsv
# Out:
# E	{(b),(g),(f)}	[jjj#3,bbb#0,ddd#9,ggg#8,hhh#2]
# A	{(a),(f),(c)}	[ccc#2,ddd#0,aaa#3,hhh#9]
# B	{(f),(e),(a),(c)}	[ddd#2,ggg#5,ccc#6,jjj#1]
# A	{(a),(b)}	[hhh#9,iii#5,eee#7,bbb#1]
# C	{(f),(g),(d),(a)}	[iii#6,ddd#5,eee#4,jjj#3]
# A	{(c),(d)}	[bbb#2,hhh#0,ccc#4,fff#1,aaa#7]
# A	{(g),(d),(a)}	[aaa#5,fff#8,ddd#2,iii#0,jjj#7,ccc#1]
# B	{(b),(a)}	[fff#3,hhh#1,ddd#2]
# E	{(d),(e),(a),(f)}	[eee#4,ccc#5,iii#9,fff#7,ggg#6,bbb#0]
# B	{(d),(b),(g),(f)}	[bbb#7,jjj#9,fff#5,iii#4,ggg#2,eee#3]
# C	{(d),(c),(f),(b)}	[hhh#6,eee#4,iii#0,fff#2,jjj#1]
# C	{(d),(e),(a),(c)}	[bbb#7,iii#6,ggg#9]
# D	{(g),(e),(f),(b)}	[bbb#9,aaa#3,ccc#6,fff#4,eee#2]
# E	{(c),(f)}	[aaa#8,ddd#5,jjj#1]
# B	{(d),(b)}	[ccc#0,jjj#6,fff#7,ddd#3,aaa#2]
# D	{(f),(e)}	[ccc#0,eee#6,bbb#9,ddd#3]
# E	{(e),(b),(f)}	[bbb#6,iii#3,hhh#5,fff#4,ggg#9,ddd#2]
# D	{(g),(a)}	[hhh#4,jjj#5,ccc#9]
# E	{(e),(c),(f),(a)}	[ccc#1,iii#6,fff#9]
# E	{(e),(a)}	[bbb#9,aaa#3,fff#1]
# E	{(e),(f)}	[ddd#9,iii#2,aaa#4]
# E	{(c),(b),(g)}	[ccc#5,fff#8,iii#7]
# D	{(c),(f),(a)}	[eee#3,jjj#2,ddd#7]
# A	{(f),(a),(d)}	[jjj#1,ggg#0,ccc#7,ddd#9,bbb#3]
# E	{(c),(d)}	[jjj#6,ccc#0,aaa#1,hhh#9,iii#7,ggg#8]
# E	{(e),(d),(c)}	[fff#3,eee#6,iii#4,bbb#7,ddd#0,ccc#1]
# A	{(a),(e),(f)}	[fff#0,ddd#5,ccc#4]
# E	{(c),(a),(g)}	[ggg#6,hhh#3,ddd#9,ccc#0,jjj#7]
# A	{(f),(e)}	[hhh#6,jjj#0,eee#5,iii#7,ccc#3]
# C	{(f),(c),(a),(g)}	[eee#1,fff#4,aaa#2,ccc#7,ggg#0,ddd#6]
# A	{(b),(f)}	[ccc#6,aaa#9,eee#5,ddd#0,bbb#3]
# D	{(b),(f)}	[bbb#7,hhh#1,aaa#6,iii#4,fff#9,ddd#5]
# E	{(a),(c)}	[fff#3,ccc#1,ggg#2,eee#5]
# B	{(b),(f),(c)}	[iii#7,ggg#3,ddd#0,jjj#8,hhh#5,ccc#1]
# B	{(f),(a),(e)}	[hhh#6,ccc#3,jjj#0,bbb#8,ddd#7]
# D	{(a),(f)}	[aaa#0,fff#5,ddd#3]
# B	{(c),(a)}	[ddd#5,jjj#2,iii#7,ccc#0,bbb#4]
# C	{(c),(a),(e),(f)}	[eee#0,fff#2,hhh#6]
# E	{(e),(d)}	[fff#9,iii#2,eee#0]
# E	{(f),(a),(d)}	[hhh#8,ggg#3,jjj#5]

# %%
# %%pig
# lines = LOAD 'data.tsv' USING PigStorage('\t') AS (
# letra:CHARARRAY,
# conjunto_tuplas:BAG{t: TUPLE(p:CHARARRAY)},
# parejas:MAP[]);
# DUMP lines;
# Out:
#  lines = LOAD 'data.tsv' USING PigStorage('\t') AS (
# letra:CHARARRAY,
# conjunto_tuplas:BAG{t: TUPLE(p:CHARARRAY)},
# parejas:MAP[]);
#  DUMP lines;
# 2020-03-06 14:05:38,308 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-06 14:05:38,640 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.job.reduce.markreset.buffer.percent is deprecated. Instead, use mapreduce.reduce.markreset.buffer.percent
# 2020-03-06 14:05:38,646 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.output.compress is deprecated. Instead, use mapreduce.output.fileoutputformat.compress
# 2020-03-06 14:05:38,677 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.submit.replication is deprecated. Instead, use mapreduce.client.submit.file.replication
# 2020-03-06 14:05:40,460 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.job.tracker.http.address is deprecated. Instead, use mapreduce.jobtracker.http.address
# 2020-03-06 14:05:40,470 [JobControl] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-06 14:05:40,513 [JobControl] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.task.id is deprecated. Instead, use mapreduce.task.attempt.id
# 2020-03-06 14:05:40,736 [JobControl] WARN  org.apache.hadoop.mapreduce.JobResourceUploader - No job jar file set.  User classes may not be found. See Job or Job#setJar(String).
# 2020-03-06 14:05:40,792 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2020-03-06 14:05:41,369 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - number of splits:1
# 2020-03-06 14:05:41,801 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - Submitting tokens for job: job_1583503056439_0001
# 2020-03-06 14:05:42,031 [JobControl] INFO  org.apache.hadoop.mapred.YARNRunner - Job jar is not present. Not adding any jar to the list of resources.
# 2020-03-06 14:05:42,455 [JobControl] INFO  org.apache.hadoop.yarn.client.api.impl.YarnClientImpl - Submitted application application_1583503056439_0001
# 2020-03-06 14:05:42,508 [JobControl] INFO  org.apache.hadoop.mapreduce.Job - The url to track the job: http://5eb5f6c70dec:8088/proxy/application_1583503056439_0001/
# 2020-03-06 14:06:07,760 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-06 14:06:07,774 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-06 14:06:09,033 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-06 14:06:09,049 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-06 14:06:09,104 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.reduce.tasks is deprecated. Instead, use mapreduce.job.reduces
# 2020-03-06 14:06:09,107 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-06 14:06:09,113 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-06 14:06:09,233 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-06 14:06:09,240 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-06 14:06:09,289 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-06 14:06:09,297 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-06 14:06:09,339 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-06 14:06:09,346 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-06 14:06:09,436 [main] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# (E,{(b),(g),(f)},[hhh#2,bbb#0,jjj#3,ddd#9,ggg#8])
# (A,{(a),(f),(c)},[aaa#3,hhh#9,ccc#2,ddd#0])
# (B,{(f),(e),(a),(c)},[ccc#6,jjj#1,ddd#2,ggg#5])
# (A,{(a),(b)},[iii#5,hhh#9,bbb#1,eee#7])
# (C,{(f),(g),(d),(a)},[iii#6,jjj#3,eee#4,ddd#5])
# (A,{(c),(d)},[aaa#7,hhh#0,ccc#4,bbb#2,fff#1])
# (A,{(g),(d),(a)},[aaa#5,iii#0,ccc#1,jjj#7,ddd#2,fff#8])
# (B,{(b),(a)},[ddd#2,hhh#1,fff#3])
# (E,{(d),(e),(a),(f)},[iii#9,ccc#5,bbb#0,eee#4,ggg#6,fff#7])
# (B,{(d),(b),(g),(f)},[iii#4,bbb#7,jjj#9,eee#3,ggg#2,fff#5])
# (C,{(d),(c),(f),(b)},[iii#0,hhh#6,jjj#1,eee#4,fff#2])
# (C,{(d),(e),(a),(c)},[iii#6,ggg#9,bbb#7])
# (D,{(g),(e),(f),(b)},[aaa#3,ccc#6,bbb#9,eee#2,fff#4])
# (E,{(c),(f)},[aaa#8,ddd#5,jjj#1])
# (B,{(d),(b)},[aaa#2,ccc#0,jjj#6,ddd#3,fff#7])
# (D,{(f),(e)},[ccc#0,bbb#9,eee#6,ddd#3])
# (E,{(e),(b),(f)},[iii#3,hhh#5,bbb#6,ddd#2,ggg#9,fff#4])
# (D,{(g),(a)},[hhh#4,ccc#9,jjj#5])
# (E,{(e),(c),(f),(a)},[iii#6,ccc#1,fff#9])
# (E,{(e),(a)},[aaa#3,bbb#9,fff#1])
# (E,{(e),(f)},[aaa#4,iii#2,ddd#9])
# (E,{(c),(b),(g)},[iii#7,ccc#5,fff#8])
# (D,{(c),(f),(a)},[eee#3,ddd#7,jjj#2])
# (A,{(f),(a),(d)},[ccc#7,bbb#3,jjj#1,ddd#9,ggg#0])
# (E,{(c),(d)},[aaa#1,iii#7,hhh#9,ccc#0,jjj#6,ggg#8])
# (E,{(e),(d),(c)},[iii#4,ccc#1,bbb#7,eee#6,ddd#0,fff#3])
# (A,{(a),(e),(f)},[ddd#5,ccc#4,fff#0])
# (E,{(c),(a),(g)},[hhh#3,ccc#0,jjj#7,ddd#9,ggg#6])
# (A,{(f),(e)},[iii#7,hhh#6,ccc#3,jjj#0,eee#5])
# (C,{(f),(c),(a),(g)},[aaa#2,ccc#7,eee#1,ddd#6,ggg#0,fff#4])
# (A,{(b),(f)},[aaa#9,ccc#6,bbb#3,eee#5,ddd#0])
# (D,{(b),(f)},[aaa#6,iii#4,hhh#1,bbb#7,ddd#5,fff#9])
# (E,{(a),(c)},[ccc#1,eee#5,ggg#2,fff#3])
# (B,{(b),(f),(c)},[iii#7,hhh#5,ccc#1,jjj#8,ddd#0,ggg#3])
# (B,{(f),(a),(e)},[hhh#6,ccc#3,bbb#8,jjj#0,ddd#7])
# (D,{(a),(f)},[aaa#0,ddd#3,fff#5])
# (B,{(c),(a)},[iii#7,ccc#0,bbb#4,jjj#2,ddd#5])
# (C,{(c),(a),(e),(f)},[eee#0,hhh#6,fff#2])
# (E,{(e),(d)},[eee#0,iii#2,fff#9])
# (E,{(f),(a),(d)},[hhh#8,ggg#3,jjj#5])

# %%
# %%pig
# conteo = FOREACH lines GENERATE letra, SIZE(conjunto_tuplas) as cantidad_conjuntos, SIZE(parejas) as cantidad_parejas;
# DUMP conteo;
# Out:
# conjuntos, SIZE(parejas) as cantidad_parejas;conjunto_tuplas) as cantidad_
#  DUMP conteo;
# 2020-03-06 14:06:09,911 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-06 14:06:10,543 [JobControl] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-06 14:06:10,569 [JobControl] WARN  org.apache.hadoop.mapreduce.JobResourceUploader - No job jar file set.  User classes may not be found. See Job or Job#setJar(String).
# 2020-03-06 14:06:10,596 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2020-03-06 14:06:11,459 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - number of splits:1
# 2020-03-06 14:06:11,919 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - Submitting tokens for job: job_1583503056439_0002
# 2020-03-06 14:06:11,926 [JobControl] INFO  org.apache.hadoop.mapred.YARNRunner - Job jar is not present. Not adding any jar to the list of resources.
# 2020-03-06 14:06:11,982 [JobControl] INFO  org.apache.hadoop.yarn.client.api.impl.YarnClientImpl - Submitted application application_1583503056439_0002
# 2020-03-06 14:06:11,991 [JobControl] INFO  org.apache.hadoop.mapreduce.Job - The url to track the job: http://5eb5f6c70dec:8088/proxy/application_1583503056439_0002/
# 2020-03-06 14:06:32,244 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-06 14:06:32,254 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-06 14:06:32,929 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-06 14:06:32,941 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-06 14:06:33,015 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-06 14:06:33,021 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-06 14:06:33,104 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-06 14:06:33,110 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-06 14:06:33,158 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-06 14:06:33,165 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-06 14:06:33,212 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-06 14:06:33,223 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-06 14:06:33,289 [main] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# (E,3,5)
# (A,3,4)
# (B,4,4)
# (A,2,4)
# (C,4,4)
# (A,2,5)
# (A,3,6)
# (B,2,3)
# (E,4,6)
# (B,4,6)
# (C,4,5)
# (C,4,3)
# (D,4,5)
# (E,2,3)
# (B,2,5)
# (D,2,4)
# (E,3,6)
# (D,2,3)
# (E,4,3)
# (E,2,3)
# (E,2,3)
# (E,3,3)
# (D,3,3)
# (A,3,5)
# (E,2,6)
# (E,3,6)
# (A,3,3)
# (E,3,5)
# (A,2,5)
# (C,4,6)
# (A,2,5)
# (D,2,6)
# (E,2,4)
# (B,3,6)
# (B,3,5)
# (D,2,3)
# (B,2,5)
# (C,4,3)
# (E,2,3)
# (E,3,3)

# %%
# %%pig
# conteo1 = ORDER conteo BY letra, cantidad_conjuntos, cantidad_parejas;
# DUMP conteo1;
# Out:
#  conteo1 = ORDER conteo BY letra, cantidad_conjuntos, cantidad_parejas;
#  DUMP conteo1;
# 2020-03-06 14:06:33,645 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-06 14:06:34,234 [JobControl] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-06 14:06:34,262 [JobControl] WARN  org.apache.hadoop.mapreduce.JobResourceUploader - No job jar file set.  User classes may not be found. See Job or Job#setJar(String).
# 2020-03-06 14:06:34,292 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2020-03-06 14:06:34,347 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - number of splits:1
# 2020-03-06 14:06:34,775 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - Submitting tokens for job: job_1583503056439_0003
# 2020-03-06 14:06:34,785 [JobControl] INFO  org.apache.hadoop.mapred.YARNRunner - Job jar is not present. Not adding any jar to the list of resources.
# 2020-03-06 14:06:34,836 [JobControl] INFO  org.apache.hadoop.yarn.client.api.impl.YarnClientImpl - Submitted application application_1583503056439_0003
# 2020-03-06 14:06:34,845 [JobControl] INFO  org.apache.hadoop.mapreduce.Job - The url to track the job: http://5eb5f6c70dec:8088/proxy/application_1583503056439_0003/
# 2020-03-06 14:06:55,154 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-06 14:06:55,165 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-06 14:06:55,327 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-06 14:06:55,333 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-06 14:06:55,372 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-06 14:06:55,378 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-06 14:06:56,430 [JobControl] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-06 14:06:56,457 [JobControl] WARN  org.apache.hadoop.mapreduce.JobResourceUploader - No job jar file set.  User classes may not be found. See Job or Job#setJar(String).
# 2020-03-06 14:06:56,478 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2020-03-06 14:06:56,524 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - number of splits:1
# 2020-03-06 14:06:56,550 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - Submitting tokens for job: job_1583503056439_0004
# 2020-03-06 14:06:56,555 [JobControl] INFO  org.apache.hadoop.mapred.YARNRunner - Job jar is not present. Not adding any jar to the list of resources.
# 2020-03-06 14:06:56,603 [JobControl] INFO  org.apache.hadoop.yarn.client.api.impl.YarnClientImpl - Submitted application application_1583503056439_0004
# 2020-03-06 14:06:56,609 [JobControl] INFO  org.apache.hadoop.mapreduce.Job - The url to track the job: http://5eb5f6c70dec:8088/proxy/application_1583503056439_0004/
# 2020-03-06 14:07:27,085 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-06 14:07:27,094 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-06 14:07:27,227 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-06 14:07:27,235 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-06 14:07:27,303 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-06 14:07:27,308 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-06 14:07:28,335 [JobControl] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-06 14:07:28,357 [JobControl] WARN  org.apache.hadoop.mapreduce.JobResourceUploader - No job jar file set.  User classes may not be found. See Job or Job#setJar(String).
# 2020-03-06 14:07:28,376 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2020-03-06 14:07:28,415 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - number of splits:1
# 2020-03-06 14:07:28,978 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - Submitting tokens for job: job_1583503056439_0005
# 2020-03-06 14:07:28,983 [JobControl] INFO  org.apache.hadoop.mapred.YARNRunner - Job jar is not present. Not adding any jar to the list of resources.
# 2020-03-06 14:07:29,045 [JobControl] INFO  org.apache.hadoop.yarn.client.api.impl.YarnClientImpl - Submitted application application_1583503056439_0005
# 2020-03-06 14:07:29,051 [JobControl] INFO  org.apache.hadoop.mapreduce.Job - The url to track the job: http://5eb5f6c70dec:8088/proxy/application_1583503056439_0005/
# 2020-03-06 14:07:54,284 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-06 14:07:54,296 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-06 14:07:54,390 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-06 14:07:54,405 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-06 14:07:54,455 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-06 14:07:54,462 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-06 14:07:54,528 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-06 14:07:54,535 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-06 14:07:54,569 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-06 14:07:54,573 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-06 14:07:54,606 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-06 14:07:54,610 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-06 14:07:54,652 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-06 14:07:54,656 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-06 14:07:54,694 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-06 14:07:54,698 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-06 14:07:54,742 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-06 14:07:54,745 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-06 14:07:54,786 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-06 14:07:54,791 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-06 14:07:54,830 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-06 14:07:54,834 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-06 14:07:54,875 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-06 14:07:54,879 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-06 14:07:54,927 [main] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# (A,2,4)
# (A,2,5)
# (A,2,5)
# (A,2,5)
# (A,3,3)
# (A,3,4)
# (A,3,5)
# (A,3,6)
# (B,2,3)
# (B,2,5)
# (B,2,5)
# (B,3,5)
# (B,3,6)
# (B,4,4)
# (B,4,6)
# (C,4,3)
# (C,4,3)
# (C,4,4)
# (C,4,5)
# (C,4,6)
# (D,2,3)
# (D,2,3)
# (D,2,4)
# (D,2,6)
# (D,3,3)
# (D,4,5)
# (E,2,3)
# (E,2,3)
# (E,2,3)
# (E,2,3)
# (E,2,4)
# (E,2,6)
# (E,3,3)
# (E,3,3)
# (E,3,5)
# (E,3,5)
# (E,3,6)
# (E,3,6)
# (E,4,3)
# (E,4,6)

# %%
# %%pig
# STORE conteo1 INTO 'output' USING PigStorage(',');
# fs -get output/ .;
# Out:
#  STORE conteo1 INTO 'output' USING PigStorage(',');
# 2020-03-06 14:07:55,093 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.textoutputformat.separator is deprecated. Instead, use mapreduce.output.textoutputformat.separator
# 2020-03-06 14:07:55,178 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-06 14:07:55,704 [JobControl] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-06 14:07:55,724 [JobControl] WARN  org.apache.hadoop.mapreduce.JobResourceUploader - No job jar file set.  User classes may not be found. See Job or Job#setJar(String).
# 2020-03-06 14:07:55,740 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2020-03-06 14:07:55,783 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - number of splits:1
# 2020-03-06 14:07:55,807 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - Submitting tokens for job: job_1583503056439_0006
# 2020-03-06 14:07:55,811 [JobControl] INFO  org.apache.hadoop.mapred.YARNRunner - Job jar is not present. Not adding any jar to the list of resources.
# 2020-03-06 14:07:55,859 [JobControl] INFO  org.apache.hadoop.yarn.client.api.impl.YarnClientImpl - Submitted application application_1583503056439_0006
# 2020-03-06 14:07:55,866 [JobControl] INFO  org.apache.hadoop.mapreduce.Job - The url to track the job: http://5eb5f6c70dec:8088/proxy/application_1583503056439_0006/
# 2020-03-06 14:08:20,969 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-06 14:08:20,980 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-06 14:08:21,067 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-06 14:08:21,075 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-06 14:08:21,104 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-06 14:08:21,109 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-06 14:08:22,867 [JobControl] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-06 14:08:22,884 [JobControl] WARN  org.apache.hadoop.mapreduce.JobResourceUploader - No job jar file set.  User classes may not be found. See Job or Job#setJar(String).
# 2020-03-06 14:08:22,900 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2020-03-06 14:08:22,949 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - number of splits:1
# 2020-03-06 14:08:22,984 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - Submitting tokens for job: job_1583503056439_0007
# 2020-03-06 14:08:22,989 [JobControl] INFO  org.apache.hadoop.mapred.YARNRunner - Job jar is not present. Not adding any jar to the list of resources.
# 2020-03-06 14:08:23,030 [JobControl] INFO  org.apache.hadoop.yarn.client.api.impl.YarnClientImpl - Submitted application application_1583503056439_0007
# 2020-03-06 14:08:23,040 [JobControl] INFO  org.apache.hadoop.mapreduce.Job - The url to track the job: http://5eb5f6c70dec:8088/proxy/application_1583503056439_0007/
# 2020-03-06 14:08:48,566 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-06 14:08:48,577 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-06 14:08:48,700 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-06 14:08:48,705 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-06 14:08:48,753 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-06 14:08:48,757 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-06 14:08:48,986 [JobControl] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-06 14:08:49,020 [JobControl] WARN  org.apache.hadoop.mapreduce.JobResourceUploader - No job jar file set.  User classes may not be found. See Job or Job#setJar(String).
# 2020-03-06 14:08:49,039 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2020-03-06 14:08:49,482 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - number of splits:1
# 2020-03-06 14:08:49,508 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - Submitting tokens for job: job_1583503056439_0008
# 2020-03-06 14:08:49,511 [JobControl] INFO  org.apache.hadoop.mapred.YARNRunner - Job jar is not present. Not adding any jar to the list of resources.
# 2020-03-06 14:08:49,572 [JobControl] INFO  org.apache.hadoop.yarn.client.api.impl.YarnClientImpl - Submitted application application_1583503056439_0008
# 2020-03-06 14:08:49,580 [JobControl] INFO  org.apache.hadoop.mapreduce.Job - The url to track the job: http://5eb5f6c70dec:8088/proxy/application_1583503056439_0008/
# 2020-03-06 14:09:19,655 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-06 14:09:19,663 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-06 14:09:19,781 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-06 14:09:19,786 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-06 14:09:19,832 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-06 14:09:19,838 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-06 14:09:19,884 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-06 14:09:19,887 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-06 14:09:19,924 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-06 14:09:19,927 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-06 14:09:19,958 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-06 14:09:19,962 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-06 14:09:20,007 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-06 14:09:20,010 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-06 14:09:20,047 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-06 14:09:20,051 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-06 14:09:20,087 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-06 14:09:20,091 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-06 14:09:20,131 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-06 14:09:20,135 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-06 14:09:20,170 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-06 14:09:20,174 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-06 14:09:20,216 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-06 14:09:20,222 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
#  fs -get output/ .;
# get: `output/_SUCCESS': File exists
# get: `output/part-r-00000': File exists

# %%
# !hadoop fs -cat output/part-r-*
# Out:
# A,2,4
# A,2,5
# A,2,5
# A,2,5
# A,3,3
# A,3,4
# A,3,5
# A,3,6
# B,2,3
# B,2,5
# B,2,5
# B,3,5
# B,3,6
# B,4,4
# B,4,6
# C,4,3
# C,4,3
# C,4,4
# C,4,5
# C,4,6
# D,2,3
# D,2,3
# D,2,4
# D,2,6
# D,3,3
# D,4,5
# E,2,3
# E,2,3
# E,2,3
# E,2,3
# E,2,4
# E,2,6
# E,3,3
# E,3,3
# E,3,5
# E,3,5
# E,3,6
# E,3,6
# E,4,3
# E,4,6

# %%
# !hadoop fs -rm output/*
# !hadoop fs -rmdir output
# Out:
# Deleted output/_SUCCESS
# Deleted output/part-r-00000
